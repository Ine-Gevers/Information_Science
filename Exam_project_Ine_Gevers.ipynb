# %%
# In this cell, I query database using sqlite, which returns get back a list of tuples.

import sqlite3
import os

# This connector will search for the file named 'stcv.sqlite' in the same directory as this notebook.
# The dot indicates the relative path connected to the same folder
conn = sqlite3.connect(os.path.join('.','stcv.sqlite'))

# Create cursor object
cur = conn.cursor()

# Use the given query
query = """
SELECT DISTINCT
    title.cloi as identifier,
    COUNT(title.cloi) as id_count,
    author_vw as author_standardized,
    author_zvwr as author_original,
    author_zbd as author_dates,
    corporateauthor_nm as corporateauthor_standardized,
    corporateauthor_zvwr as corporateauthor_original,
    title_ti as title_title,
    title_lg as title_language,
    collation_fm as format,
    collation_ka as quires,
    collation_pg as pages,
    edition_ed as edition_info,
    impressum_ju1sv as year1,
    impressum_ju1ty as year1_type,
    impressum_ju2sv as year2,
    impressum_ju2ty as year2_type,
    impressum_pl as place,
    impressum_ug as printer,
    language_lg as language_info,
    number_nr as fingerprint
    FROM title
LEFT JOIN author on author.cloi = title.cloi
LEFT JOIN collation on collation.cloi = title.cloi
LEFT JOIN corporateauthor on corporateauthor.cloi = title.cloi
LEFT JOIN edition on edition.cloi = title.cloi
LEFT JOIN impressum on impressum.cloi = title.cloi
LEFT JOIN language on language.cloi = title.cloi
LEFT JOIN number on number.cloi = title.cloi
GROUP BY identifier
HAVING ID_COUNT=2
LIMIT 100
"""

# I execute the query
cur.execute(query)

# I iterate over every match and create a list consisting of all resulting rows
data = [row for row in cur.fetchall()]
for row in data:
    print(row)

# Close the database connection
conn.close()
# Out:
# ('c:stcv:12854444', 2, 'Ernst, Simon-Pierre', 'S.P. Ernst', '1744-1817', None, None, 'Apologie des ministres du culte, qui ont prêté la déclaration exigée par la loi du 7 vendém. an 4. contre les critiques de mm. Dédoyar & Vanhoren, les Motifs de Malines & autres brochures', 'fre', '', 'π<sup>2</sup> a<sup>8</sup> b<sup>4</sup> A-H<sup>8</sup> I<sup>6</sup> (- I6) K<sup>2</sup>', 'xxviij, 142 p.', None, '1797', 'YYYY', '', 'YYYY', 's.l.', 's.n.', 'fre', '179708 - # a1 a é : # a2 b2 e, - # b1 A t : # b2 K $a')
# ('c:stcv:12854501', 2, 'Ernst, Simon-Pierre', 'S.P. Ernst', '1744-1817', None, None, 'Observations sur la déclaration exigée des ministres des cultes, en vertu de la loi du 7 vendémiaire, an 4', 'fre', '', 'π1 A<sup>8</sup> B-D<sup>4</sup> E<sup>4</sup> (- E1)', '[1], [1 blank], 45, [1 blank] p.', None, '1797', 'YYYY', '', 'YYYY', 's.l.', 's.n.', 'fre', '179708 - # b1 A2 vais : # b2 E m')
# ('c:stcv:12854549', 2, 'Gisbert, Blaise', 'Gisbert', '1657-1731', None, None, "l'Eloquence chrétienne dans l'idée et dans la pratique", 'fre', '', '*<sup>4</sup> <sup>2</sup>*<sup>8</sup> (- *1-3) A-2B<sup>8</sup> 2C<sup>4</sup>', '[1], [1 blank], [16], 358, [50] p.', 'New edition', '1763', 'YYYY', '', 'YYYY', 'Louvain', 'Jean Francois van Overbeke', 'fre', '176308 - # a1 *2. cat : # a2 *4 lo - # b1 A $ : # b2 2C3 nnon')
# ('c:stcv:12854587', 2, None, None, None, None, None, 'Verscheyde leeringen en exempelen der oude vaders', 'dut', '', 'A-K<sup>12</sup> L<sup>6</sup>', '252 p.', None, '1771', '(YYYY-)', '', 'YYYY', 'Gend', 'Jan Meyer', 'dut', '000012 - # b1 A2 rpe : # b2 L3 ,$z')
# ('c:stcv:12854599', 2, None, None, None, None, None, 'Godtvruchtige leeringen en gebeden voor de eerste communie', 'dut', '', 'A<sup>12</sup>', '24 p.', None, '1745', '(YYYY-)', '', 'YYYY', 's.l.', 's.n.', 'dut', '000012 - # b1 A o : # b2 A7 ck$d')
# ('c:stcv:12857052', 2, 'Courvoisier, Jean-Jacques', 'Iean Iacques Couruoisier', '', None, None, "Le prince immortel tiré sur la vie & la fin glorieuse de son altesse royale don Ferdinand d'Avstriche", 'fre', '', 'π1 ...<sup>4</sup> (:)<sup>2</sup> A-N<sup>4</sup>', '[1 blank], [2], [1 blank], [10], 102, [2] p.', None, '1642', 'YYYY', '', 'YYYY', 'Anvers', 'Cæsar Ioachim Trognæsius', 'fre', '164204 - # 1a1 ...2 à$la$ : # 1a2 ...3 t$di - # 2a1=2a2 (:) mu - # b1 A o : # b2 N3 $en')
# ('c:stcv:12857069', 2, 'Choquet, François Hyacinthe', 'Franciscus Hyacinthus Choqvetius', '1581-1645', None, None, 'Trivmphvs rosarii a sede apostolica decretvs sodalitati B. virginis Mariæ', 'lat', '', '*<sup>8</sup> A-R<sup>8</sup> S<sup>4</sup>', '[1], [1 blank], [14], 277, [2], [1 blank] p.', None, '1641', 'YYYY', '', 'YYYY', 'Antverpiæ', 'apud Gvilielmvm Lesteenivm', 'lat', '164108 - # a1 *2 $ : # a2 *4 æ$ - # b1 A t : # b2 S3 Se')
# ('c:stcv:12857131', 2, 'Lancelottus, Lucas', 'Lvcas Lancelottus', '', None, None, 'In statvas antiqvitatis et elegantias Arvndellianas cento Maronianvs', 'lat', '', '[A]<sup>4</sup>', '[4] f.', None, '1643', '(col.YYYY)', '', 'YYYY', 'Antverpiæ', 'apvd Martinvm Binnart', 'lat', '000002 - # b1 TERRA ISCEL : # b2 252 10')
# ('c:stcv:12857158', 2, None, None, None, None, None, 'Inde[x] librorvm qvi in typographia Plantiniana excvsi venales nvnc exstant', 'lat', '', 'A-E<sup>8</sup>', '79, [1 blank] p.', None, '1642', 'YYYY', '', 'YYYY', 'Antverpiæ', 'ex officina Plantiniana Balthasaris Moreti', 'lat', '164208 - # b1 A2 $Li : # b2 E5 er-')
# ('c:stcv:12857275', 2, 'Pauwels, Nicolaus', 'Nicolaus Pauwels', '-1713', None, None, 'Theologiæ practicæ in qua de actibus humanis [...] agitur [...] pars quarta', 'lat', '', 'A-Y<sup>12</sup>', '519, [7], [2 blank] p.', 'Third edition, enlarged and corrected', '1741', 'YYYY', '', 'YYYY', 'Lovanii', 'typis Martini van Overbeke', 'lat', '174112 - # b1 A2 ora : # b2 Y6 ,$C')
# ('c:stcv:12857374', 2, 'Noot, van der, Henri Charles Nicolas', 'H.C.N. van der Noot', '1731-1827', None, None, 'Gedenk-stuk op de geregtigheden der Brabanders, en de beledigingen, die tegen de zelve geschied zyn uyt den naem van S.M. den keyzer en koning, sedert eenige jaeren', 'dut', '', '[A]<sup>4</sup> ([A]1 + π<sup>2</sup>) B-O<sup>4</sup>', '112 [= 116] p.', None, '1787', '(YYYY-)', '', 'YYYY', 'Antwerpen', 'C.M. Spanoghe', 'dut', '000008 - # b1 B r : # b2 O $')
# ('c:stcv:12857912', 2, 'Drexelius, Hieremias', 'Hieremias Drexelius', '1581-1638', None, None, 'David regivs psaltes descriptvs', 'lat', '', '*<sup>12</sup> A-Q<sup>12</sup> (Q12 blank)', '[1], [1 blank], [22], 379, [2], [3 blank] p.', None, '1643', 'YYYY', '', 'YYYY', 'Antverpiæ', 'apud viduam et hæredes Ioannis Cnobbari', 'lat', '164312 - # a1 *2 ,$n : # a2 *7 os, - # b1 A $ : # b2 Q6 ra.$')
# ('c:stcv:12857923', 2, 'member of the fraternity of the Holy Cross [Hoboken]', 'N.N. cofrade de la misma cofradia', '', None, None, 'Librito de la cofradia de la s.ta Crvz de Hoboqve de la dioceis de Anberes', 'spa', '', 'A-G<sup>12</sup>', '167, [1] p.', 'Translated from the Latin', '1643', 'YYYY', '', 'YYYY', 'Anberes', 'Theodato Verulst', 'spa', '164304 - # b1 A2 do$ : # b2 G7 e$es')
# ('c:stcv:12858124', 2, 'M.Æ.V.D.V.', 'M.Æ.V.D.V.', '', None, None, 'Het vereerlykt Oostenryk, in den oorlog tegen den koning van Pruyssen', 'dut', '', '[A]<sup>4</sup> B-S<sup>4</sup>', '142, [1], [1 blank] p.', None, '1779', 'inter[YYYY-YYYY]', '', 'YYYY', 'Gend', 'J.F. vander Schueren', 'dut', '000008 - # b1 B h$ : # b2 S rsc')
# ('c:stcv:12858392', 2, 'Drexelius, Hieremias', 'Hieremias Drexelius', '1581-1638', None, None, 'Tobias morali doctrinâ illustratus [...] ex posthumis libellis quartus. Monachii M.DC.XLI.', 'lat', '', '*<sup>8</sup> A-T<sup>12</sup> V<sup>4</sup> (V4 blank)', '[1], [1 blank], [14], 459, [3], [2 blank] p.', None, '1642', 'YYYY', '', 'YYYY', 'Antuerp.', 'typis vid. Ioann. Cnobbari', 'lat', '164212 - # a1 *2 ssi : # a2 *4 enti - # b1 A om : # b2 V it')
# ('c:stcv:12858408', 2, 'Drexelius, Hieremias', 'Hieremias Drexelius', '1581-1638', None, None, 'Aloe amari sed salubris succi ieivnivm', 'lat', '', 'A-P<sup>12</sup> (P11-12 blank)', '[1], [1 blank], [16], 336, [1], [5 blank] p.', None, '1643', 'YYYY', '', 'YYYY', 'Antuerpiæ', 'typis vid. Ioann. Cnobbari', 'lat', '164312 - # b1 A2 ine : # b2 P6 mb')
# ('c:stcv:12858413', 2, 'Drexelius, Hieremias', 'Hieremias Drexelius', '1581-1638', None, None, 'Rosæ selectissimarum virtutum, quas Dei mater orbi exhibet, pars II.', 'lat', '', 'a-t<sup>12</sup> u<sup>12</sup> (u11-12 blank)', '475, [5 blank] p.', None, '1641', 'YYYY', '', 'YYYY', 'Antverpiæ', 'apud viduam Joannis Cnobari', 'lat', '164112 - # b1 a2 irt : # b2 u6 $su')
# ('c:stcv:12858468', 2, 'Cicero, Marcus Tullius', 'M. Tvllius Cicero', '106 ante Chr.-43 ante Chr.', None, None, 'Orationvm volvmen II.', 'lat', '', 'π<sup>2</sup> A-2M<sup>8</sup> 2N<sup>6</sup>', '[1], [1 blank], [2], 571, [1 blank] p.', 'Corrected', '1643', 'YYYY', '', 'YYYY', 'Antverpiæ', 'apud Petrvm Bellervm', 'lat', '164308 - # b1 A dice : # b2 2N4 ræclar')
# ('c:stcv:12858494', 2, None, None, None, None, None, "Nouvvelle chronicqve contenant les choses plus memorables advenues en ces Pays-bas, depuis l'an 1500. jusques à l'an present", 'fre', '', 'A-B<sup>16</sup>', '[32] f.', None, '1644', '[YYYY]', '', 'YYYY', 'Anvers', 'vefve de Iean Cnobbart', 'fre', '000016 - # b1 A2 $le$ : # b2 B4 ce')
# ('c:stcv:12858622', 2, 'Busaeus, Joannes', 'Ioannes Bvsæus', '1547-1611', None, None, 'Enchiridion piarvm meditationvm in omnes dominicas', 'lat', '', 'A-3C<sup>8</sup> 3D<sup>4</sup> (3D4 blank)', '766, [24], [2 blank] p.', None, '1644', 'YYYY', '', 'YYYY', 'Antverpiæ', 'apud Henricum Aertssens', 'lat', '164424 - # b1 A2 Fra : # b2 3D ignit')
# ('c:stcv:12858690', 2, 'Andries, Judocus', 'Iudocus Andries', '1588-1658', None, None, 'Pvrgatorivm catholicè assertum', 'lat', '', 'a<sup>6</sup> A-K<sup>12</sup>', '[1], [1 blank], [10], 240 p.', None, '1642', 'YYYY', '', 'YYYY', 'Brvgis', 'typis Nicolai Breyghelii', 'lat', '164212 - # a1 a2 P : # a2 a3 T - # b1 A2 ,$pro : # b2 K6 u$')
# ('c:stcv:12858729', 2, 'Malvezzi, Virgilio', 'Virgilio Malvezzi', '1599-1653', None, None, "Svccessi principali della monarchia di Spagna nell'anno M.DC.XXXIX.", 'ita', '', 'A-L<sup>12</sup> M<sup>6</sup> (lacks M6, blank?)', '270, [3], [1 blank] p.', None, '1641', 'YYYY', '', 'YYYY', 'Anversa', 'Officina Plantiniana', 'ita', '164112 - # b1 A2 itta : # b2 M3 o$C')
# ('c:stcv:12858795', 2, 'Caramuel de Lobkowitz, Juan', 'Ioannes Caramvel Lobkovvitz', '1606-1682', None, None, 'Solis et artis adulteria', 'lat', '', ')-(<sup>2</sup> A-F<sup>4</sup> H<sup>2</sup> I<sup>4</sup> K<sup>2</sup> L-P<sup>4</sup> Q1 (and 1 woodcut)', '[1], [1 blank], [2], 112 [= 113], [1] p.', None, '1644', 'YYYY', '', 'YYYY', 'Lovanii', 'apud Andream Bouvetium', 'lat', '164402 - # a1=a2 )-(2 hor - # b1 A si : # b2 Q s,$')
# ('c:stcv:12859250', 2, 'Linden, van der, Jan', 'Ian vander Linden', '-1638', None, None, 'Heerlycke ende gheluckighe reyse na het Heyligh Landt ende de stadt van Jerusalem [...]. Het eerste deel', 'dut', '', 'A-D<sup>8</sup> E<sup>4</sup>', '72 p.', 'Latest impression', '1687', 'inter[YYYY-YYYY]', '', 'YYYY', 'Antwerpen', 'Hieronymus Verdussen', 'dut', '000004 - # b1 A2 $in : # b2 E2 en')
# ('c:stcv:12859427', 2, 'Faber, Matthias', 'Faber, Matthias', '1587-1653', None, None, 'Conciones funebres et nuptiales', 'lat', '', 'A-T<sup>4</sup>', '247 [= 147], [4], [1 blank] p.', None, '1663', '[YYYY]', '', 'YYYY', 'Antwerp', 'Verdussen, Hieronymus III & Joannes Baptista I', 'lat', '000002 - # b1 A v : # b2 T ,$')
# ('c:stcv:12859712', 2, 'Pomey, François', 'Franciscus Pomey', '1618-1673', None, None, 'Novus candidatus rhetoricæ', 'lat', '', 'A-X<sup>12</sup> Y<sup>6</sup>', '[1], [1 blank], [4], 489, [20], [1 blank] p.', None, '1698', 'YYYY', '', 'YYYY', 'Antverpiæ', 'apud Joannem Baptistam Verdussen', 'lat', '169812 - # b1 A2 eperi : # b2 Y4 tio')
# ('c:stcv:12859754', 2, 'Chifflet, Philippe', 'Philippus Chiffletius', '1597-1657', 'Council of Trent', 'Concilium Tridentinum', 'Sacrosancti et œcvmenici concilii Tridentini [...] canones et decreta', 'lat', '', '*<sup>12</sup> A-Q<sup>12</sup> R<sup>6</sup>', '[1], [1 blank], [22], 270, LVI, [70] p.', None, '1675', 'inter[YYYY-YYYY]', '', 'YYYY', 'Antverpiæ', 'apud Joan. Bapt. Verdussen', 'lat', '000012 - # a1 *2 tia : # a2 *6 se$ - # b1 A i : # b2 R4 m$')
# ('c:stcv:12859820', 2, 'Saavedra de Fajardo, Diego', 'Diego Saavedra Faxardo', '-1648', None, None, 'Corona gothica, castellana, y avstriaca', 'spa', '', '*-2*<sup>4</sup> A-3X<sup>4</sup>', '[1], [1 blank], [14], 513, [23] p.', None, '1658', 'YYYY', '', 'YYYY', 'Amberes', 'Ieronymo y Iuan Bapt. Verdvssen', 'spa', '165804 - # a1 *2 ra$q : # a2 2*2 o,$y$ - # b1 A ge : # b2 3X3 s$Episc')
# ('c:stcv:12859871', 2, 'Limon, de, Geoffroi', 'de Limon', '', None, None, 'La vie et le martyre de Louis XVI [...] immolé le 21 janvier 1793; avec un examen du décret régicide', 'fre', '', 'π1 A-E<sup>8</sup> F<sup>2</sup> G1', '[2], 86 p.', 'Second edition, corrected and enlarged by the author', '1793', 'YYYY', '', 'YYYY', 'Bruxelles', 'Benoit le Francq', 'fre', '179308 - # b1 A Vo : # b2 G n')
# ('c:stcv:12859905', 2, None, None, None, None, None, "Traité touchant la suppression de la mendicité et l'administration des pauvres dans la ville d'Anvers", 'fre', '', '[A]<sup>8</sup> B-E<sup>8</sup> F<sup>12</sup>', '87, [16], [1 blank] p.', None, '1780', 'YYYY', '', 'YYYY', 'Anvers', 'J. Grangé', 'fre', "178008 - # b1 B or : # b2 F 'i")
# ('c:stcv:12859931', 2, None, None, None, None, None, 'Recueil de loix concernant le régime hypothécaire a les déclarations foncieres', 'fre', '', 'A-D<sup>12</sup> E<sup>6</sup> (and 1 folding table)', '107, [1 blank] p.', None, '1796', '(YYYY-)', '', 'YYYY', 'Bruxelles', 'Tutot', 'fre', '000012 - # b1 A se : # b2 E3 ,$G')
# ('c:stcv:12860028', 2, 'Becanus, Martin', 'Martinus Becanus', '1563-1624', None, None, 'Analogia Veteris ac Novi Testamenti', 'lat', '', '*<sup>8</sup> A-2F<sup>8</sup> (2F8 blank)', 'xv, [1], 462, [2 blank] p.', 'Latest edition, corrected', '1754', 'YYYY', '', 'YYYY', 'Lovanii', 'apud Martinum van Overbeke', 'lat', '175408 - # a1 *2 s$p : # a2 *4 lig - # b1 A on : # b2 2F4 mysti')
# ('c:stcv:12860136', 2, 'Balbany, André Christophe', 'Balbany, André Christophe', '1723-[1788-]', None, None, 'Appèl a la raison des écrits et libelles publiés par la passion, contre les jésuites de France', 'fre', '', 'A-2G<sup>4/2</sup> 2H<sup>2</sup>', '[1], [1 blank], vj, 175, [1 blank] p.', None, '1762', 'YYYY', '', 'YYYY', 'Bruxelles', 'Vandenberghen', 'fre', '176212 - # b1 A2 $ici : # b2 2H tre$')
# ('c:stcv:12860498', 2, None, None, None, None, None, 'Copy van een seecker boecxken dat onlanckx is vvt ghegaen, trackterende van een miraeckel oft spectakel, dat te Amsterdam geschiet is', 'dut', '', 'G<sup>4</sup>', '7, [1 blank] p.', 'Translated into Dutch', '1620', '[YYYY]', '', 'YYYY', 'Gras-rijck [= Antwerpen]', 'Verhoeven, Abraham', 'dut', '000004 - # b1=b2 G2 $m')
# ('c:stcv:12860697', 2, 'Chifflet, Philippe', 'Philippus Chiffletius', '1597-1657', 'Council of Trent', 'Concilium Tridentinum', 'Sacrosancti et œcvmenici concilii Tridentini [...] canones et decreta', 'lat', '', '*<sup>12</sup> A-R<sup>12</sup> S<sup>8</sup>', '[1], [1 blank], [22], 287, [1 blank], LX, [76] p.', None, '1674', 'YYYY', '', 'YYYY', 'Antverpiæ', 'apud Hieronymvm et Ioa.n Bap. Verdvssen', 'lat', '167412 - # a1 *2 st,$ : # a2 *6 os$ - # b1 A a : # b2 S5 or')
# ('c:stcv:12860711', 2, 'Chifflet, Philippe', 'Philippus Chiffletius', '1597-1657', 'Council of Trent', 'Concilium Tridentinum', 'Sacrosancti et œcvmenici concilii Tridentini [...] canones et decreta', 'lat', '', '§<sup>12</sup> A-R<sup>12</sup> S<sup>8</sup>', '[1], [1 blank], [22], 287, [1 blank], LX, [76] p.', None, '1677', 'YYYY', '', 'YYYY', 'Antverpiæ', 'apud Hieronymvm Verdvssen', 'lat', '167712 - # a1 §2 pe$e : # a2 §6 pt - # b1 A s : # b2 S5 re')
# ('c:stcv:12860736', 2, 'Chifflet, Philippe', 'Philippus Chiffletius', '1597-1657', 'Council of Trent', 'Concilium Tridentinum', 'Sacrosancti et œcvmenici concilii Tridentini [...] canones et decreta', 'lat', '', '*<sup>12</sup> A-Q<sup>12</sup> R<sup>6</sup>', '[1], [1 blank], [22], 270, LVI, [70] p.', None, '1675', 'inter[YYYY-YYYY]', '', 'YYYY', 'Antverpiæ', 'apud Ioan: Bapt. Verdvssen', 'lat', '000012 - # a1 *2 hoc : # a2 *6 s$e - # b1 A s$ : # b2 R4 um')
# ('c:stcv:12861541', 2, 'Ovid', 'Pvb. Ovidius Naso', '43 ante Chr.-18', None, None, 'Fastorvm libri VI. Tristivm libri V. De ponto libri IV. In Ibin ad Liviam', 'lat', '', 'A-S<sup>12</sup>', '431, [1] p.', None, '1700', 'YYYY', '', 'YYYY', 'Antverpiæ', 'apud Hieronÿmúm Verdússen', 'lat', '170012 - # b1 A2 iss : # b2 S7 s,')
# ('c:stcv:12861606', 2, 'Chifflet, Philippe', 'Philippus Chiffletius', '1597-1657', 'Council of Trent', 'Concilium Tridentinum', 'Sacrosancti et œcvmenici concilii Tridentini [...] canones et decreta', 'lat', '', '*<sup>12</sup> A-Q<sup>12</sup> R<sup>6</sup>', '[1], [1 blank], [22], 270, LVI, [70] p.', None, '1675', 'inter[YYYY-YYYY]', '', 'YYYY', 'Antverpiæ', 'apud Joan. Bapt. Verdussen', 'lat', '000012 - # a1 *2 oc$e : # a2 *6 se$c - # b1 A $& : # b2 R4 ciu')
# ('c:stcv:12861734', 2, 'Cicero, Marcus Tullius', 'M. T. Cicero', '106 ante Chr.-43 ante Chr.', None, None, 'De officiis libri tres. Cato major, vel de senectute. Lælius, vel de amicitia. Paradoxa stoicorum sex. Somnium Scipionis', 'lat', '', 'A-X<sup>8</sup>', '280, [56] p.', None, '1673', 'YYYY', '', 'YYYY', 'Antverpiæ', 'apud Hieronymvm et Ioan. Bapt. Verdvssen', 'lat', '167324 - # b1 A2 a, : # b2 X5 al')
# ('c:stcv:12861760', 2, 'Cicero, Marcus Tullius', 'M. T. Cicero', '106 ante Chr.-43 ante Chr.', None, None, 'De officiis libri tres. Cato major, vel de senectute. Lælius, vel de amicitia. Paradoxa stoicorum sex. Somnium Scipionis', 'lat', '', 'A-X<sup>8</sup>', '280, [56] p.', None, '1673', 'YYYY', '', 'YYYY', 'Antverpiæ', 'apud Hieronymvm et Ioan. Bapt. Verdvssen', 'lat', '167324 - # b1 A2 a, : # b2 X5 atio')
# ('c:stcv:12861798', 2, 'Seneca [Younger]', 'L. Annæus Seneca', 'Ca. 4 n.Chr.-65 n.Chr.', None, None, 'Flores, ex operibus illius singulari judicio selecti', 'lat', '', 'A-K<sup>12</sup> L<sup>6</sup>', '242, [10] p.', None, '1681', 'YYYY', '', 'YYYY', 'Antverpiæ', 'apud Joannem Baptistam Verdussen', 'lat', '168112 - # b1 A2 o, : # b2 L4 urr')
# ('c:stcv:12861813', 2, 'Chifflet, Philippe', 'Philippus Chiffletius', '1597-1657', 'Council of Trent', 'Concilium Tridentinum', 'Sacrosancti et œcvmenici concilii Tridentini [...] canones et decreta', 'lat', '', '*<sup>12</sup> A-R<sup>12</sup> S<sup>8</sup>', '[1], [1 blank], [22], 287, [1 blank], LX, [76] p.', None, '1677', 'YYYY', '', 'YYYY', 'Antverpiæ', 'apud Hieronymvm Verdvssen', 'lat', '167712 - # a1 *2 st,$l : # a2 *6 os$ - # b1 A s : # b2 S5 m$')
# ('c:stcv:12862032', 2, None, None, None, None, None, 'Les provinciaux détrompés. Comédie en trois actes', 'fre', '', 'A-C<sup>8</sup> D<sup>4</sup>', '55, [1] p.', None, '1771', 'YYYY', '', 'YYYY', 'Bruxelles', 'J. van den Berghen', 'fre', '177108 - # b1 A3 $de : # b2 D2 ettr')
# ('c:stcv:12862035', 2, None, None, None, None, None, "l'Heureuse pêche, comédie pour les ombres a scenes changeantes", 'fre', '', 'A-C<sup>8</sup> D<sup>2</sup>', '49, [2], [1 blank] p.', None, '1771', 'YYYY', '', 'YYYY', 'Bruxelles', 'J. van den Berghen', 'fre', "177108 - # b1 A3 r$l'e : # b2 C3 anq")
# ('c:stcv:12862038', 2, "Allainval, d', Léonor-Jean-Christine Soulas", "d'Allainval", '1700-1753', None, None, "l'Ecole des bourgeois, comédie en trois actes", 'fre', '', 'π1 A-E<sup>8</sup> F<sup>6</sup>', '[2], 89, [2], [1 blank] p.', None, '1770', 'YYYY', '', 'YYYY', 'Bruxelles', 'J. van den Berghen', 'fre', '177008 - # b1 A $ : # b2 F3 .$')
# ('c:stcv:12862053', 2, 'Favart, Charles-Simon', 'Favart', '1710-1792', None, None, 'La rosiere de Salenci, comédie en trois actes', 'fre', '', '*<sup>4</sup> A-F<sup>8</sup> G<sup>4</sup>', 'vj, 105, [1] p.', None, '1770', 'YYYY', '', 'YYYY', 'Bruxelles', 'J. van den Berghen', 'fre', '177008 - # a1=a2 *2 eur - # b1 A $ : # b2 G m')
# ('c:stcv:12862058', 2, 'Darcis', 'Darcis', '', None, None, 'Le bal masqué, opéra-comique en un acte', 'fre', '', 'A-B<sup>8</sup> (lacks B8, blank?)', '30 p.', None, '1772', 'YYYY', '', 'YYYY', 'Bruxelles', 'J. vanden Berghen', 'fre', '177208 - # b1 A4 ur$n : # b2 B3 uis$')
# ('c:stcv:12862118', 2, 'Beaumarchais, de, Pierre Augustin Caron', 'de Beaumarchais', '1732-1799', None, None, 'Les deux amis, ou Le négociant de Lyon, drame en cinq actes en prose', 'fre', '', 'A-H<sup>8</sup> I<sup>4</sup>', '136 p.', None, '1770', 'YYYY', '', 'YYYY', 'Bruxelles', 'J. van den Berghen', 'fre', '177008 - # b1 A2 ra$ : # b2 I2 pp')
# ('c:stcv:12862125', 2, 'Billardon de Sauvigny, Louis Edmé', 'de Sauvigny', '1736-1812', None, None, 'Le persifleur, comédie en trois actes et en vers', 'fre', '', 'a/A<sup>8</sup> B-E<sup>8</sup> (lacks E8, blank?)', 'ix, [1], 67, [1] p.', None, '1771', 'YYYY', '', 'YYYY', 'Bruxelles', 'J. vanden Berghen', 'fre', '177108 - # a1=a2 a $ - # b1 A i : # b2 E4 écrit')
# ('c:stcv:12862153', 2, 'Barthe, Nicolas Thomas', 'Barthe', '1734-1785', None, None, 'La mere jalouse, comédie en trois actes et en vers', 'fre', '', 'A-F<sup>8</sup> (lacks F7-8, blank?)', '92 p.', None, '1772', 'YYYY', '', 'YYYY', 'Bruxelles', 'J. vanden Berghen', 'fre', '177208 - # b1 A2 u$p : # b2 F4 s$fa')
# ('c:stcv:12862168', 2, 'Armand', 'Armand', '1699-1765', None, None, 'Le cri de la nature, comédie en vers et en un acte', 'fre', '', 'A-C<sup>8</sup> (lacks C8, blank?)', '44, [2] p.', None, '1771', 'YYYY', '', 'YYYY', 'Bruxelles', 'J. vanden Berghen', 'fre', '177108 - # b1 A2 s$en : # b2 C3 ac')
# ('c:stcv:12863004', 2, 'Sylvius, Franciscus', 'Franciscus Silvius', '', None, None, 'Commentarii in totam primam partem S. Thom. Aqvinatis', 'lat', '', 'ã<sup>6</sup> *<sup>6</sup> 2*<sup>2</sup> A-3E<sup>6</sup> 3F-3G<sup>4</sup> 3H-3O<sup>6</sup> 3P<sup>4</sup> (3P4 blank)', '[1], [1 blank], [1], [1 blank], [24], 626, [92], [2 blank] p.', 'Fourth edition', '1684', 'YYYY', '', 'YYYY', 'Antverpiæ', 'prostant apud Joannem Baptistam Verdussen', 'lat', '168402 - # *1a1 ã3 rijs : # *1a2 ã4 in - # *2a1 * $c : # *2a2 2* on - # *b1 A im : # *b2 3P3 is,$102.$')
# ('c:stcv:12865436', 2, 'Sylvius, Franciscus', 'Franciscus Sylvius', '', None, None, 'Opera omnia, sex tomis comprehensa', 'lat', '', 'π1 and 6 separately entered volumes', '[1] f.', None, '1698', '[YYYY-]', '', 'YYYY', 'Antwerp', 'Wesenbeeck, van, Sara Anna & Joannes Baptista I Verdussen [Son]', 'lat', '000002')
# ('c:stcv:12865677', 2, 'Cygne, du, Martin', 'Martinus du Cygne', '1619-1669', None, None, 'Ars rhetorica', 'lat', '', 'A-F<sup>12</sup>', '140, [3], [1 blank] p.', 'Latest edition, corrected', '1720', 'inter[YYYY-YYYY]', '', 'YYYY', 'Antverpiæ', 'apud Martinum Verdussen', 'lat', '000012 - # b1 A2 o : # b2 F6 sa$')
# ('c:stcv:12865828', 2, 'Polman, Joannes', 'Joannes Polmannus', '', None, None, 'Breviarium theologicum continens definitiones, descriptiones, & explicationes terminorum theologicorum', 'lat', '', 'A-2L<sup>8</sup> 2M<sup>4</sup>', '[1], [1 blank], [2], 488, [60] p.', 'Latest edition, enlarged', '1686', 'YYYY', '', 'YYYY', 'Antverpiæ', 'apud Hieronymum Verdussen juniorem', 'lat', '168608 - # b1 A3 m$ : # b2 2M2 ere$p')
# ('c:stcv:12866841', 2, 'Bauvin, Jean-Grégoire', 'Bauvin', '', None, None, 'Les chérusques, tragédie', 'fre', '', 'A-D<sup>8</sup> E<sup>4</sup>', '[1], [1 blank], v, [1], 64 p.', None, '1773', 'YYYY', '', 'YYYY', 'Bruxelles', 'J. vanden Berghen', 'fre', '177308 - # b1 A2 e$P : # b2 E2 $P')
# ('c:stcv:12866854', 2, 'Rousseau, Jean-Jacques', 'J.J. Rousseau', '1712-1778', None, None, 'Pygmalion, scene lyrique', 'fre', '', 'A<sup>8</sup> (lacks A8, blank?)', '14 p.', None, '1772', 'YYYY', '', 'YYYY', 'Bruxelles', 'J. vanden Berghen', 'fre', "177208 - # b1 A2 $s'e : # b2 A4 $&$c")
# ('c:stcv:12866862', 2, None, None, None, None, None, "l'Orphelin anglais, drame, en trois actes, en prose", 'fre', '', 'A-D<sup>8</sup> E<sup>4</sup>', '71, [1] p.', None, '1770', 'YYYY', '', 'YYYY', 'Bruxelles', 'J. van den Berghen', 'fre', '177008 - # b1 A3 $mo : # b2 E2 nt$')
# ('c:stcv:12866867', 2, None, None, None, None, None, 'Bélisaire, drame en cinq actes et en vers', 'fre', '', '<sup>π</sup>A<sup>4</sup> A-D<sup>8</sup> E<sup>2</sup>', 'vij, [1], 68 p.', None, '1772', 'YYYY', '', 'YYYY', 'Bruxelles', 'J. vanden Berghen', 'fre', '177208 - # a1 A2 t$ : # a2 A3 $ma - # b1 A ou : # b2 E2 tre')
# ('c:stcv:12866905', 2, 'Favart, Charles-Simon', 'Favart, Charles-Simon', '1710-1792', None, None, "l'Amant déguisé ou Le jardinier supposé, comédie en un acte", 'fre', '', 'π<sup>2</sup> A-B<sup>8</sup> C<sup>6</sup>', '[1], [1 blank], [2], 42, [2] p.', None, '1769', 'YYYY', '', 'YYYY', 'Bruxelles', 'J. vanden Berghen', 'fre', '176908 - # b1 A m : # b2 C3 on$')
# ('c:stcv:12866912', 2, 'Goldoni, Carlo', 'Goldoni', '1707-1793', None, None, 'Le bourru bienfaisant, comédie en trois actes et en prose', 'fre', '', 'A-F<sup>8</sup> G<sup>4</sup> (lacks G4, blank?)', '102 p.', None, '1772', 'YYYY', '', 'YYYY', 'Bruxelles', 'J. vanden Berghen', 'fre', '177208 - # b1 A2 éj : # b2 G2 tém')
# ('c:stcv:12866920', 2, 'Ribadière, de la', 'de la Ribardiere', '', None, None, 'Les aveux indiscrets, opera comique', 'fre', '', 'A-B<sup>8</sup>', '28, 4 p.', None, '1759', '(YYYY-)', '', 'YYYY', 'Bruxelles', 'JJ. Boucherie', 'fre', '000008 - # b1 B2 re. : # b2 B3 atri')
# ('c:stcv:12866939', 2, None, None, None, None, None, 'Le maître en droit, opera-comique en deux actes', 'fre', '', 'A-C<sup>8</sup> D<sup>2</sup>', '51, [1] p.', None, '1760', 'YYYY', '', 'YYYY', 'Bruxelles', 'JJ. Boucherie', 'fre', '176008 - # b1 A2 ce$ : # b2 D $')
# ('c:stcv:12867300', 2, 'Moens, Adrianus', 'Adrianus Moens', '', None, None, 'Enchiridion religiosorvm', 'lat', '', 'A-K<sup>8</sup>', '149, [11] p.', None, '1646', 'YYYY', '', 'YYYY', 'Antverpiæ', 'apud Gvilielmvm Lesteenivm', 'lat', '164608 - # b1 A3 n$c : # b2 K5 t$n')
# ('c:stcv:12867792', 2, 'Woestwinckel, Petrus', 'Woestwinckel, Petrus', '1595-1673', None, None, 'Mariæ virginis [...] excellentia, potentia, misericordia; compendio exposita', 'lat', '', '*<sup>8</sup> A-H<sup>12</sup> I<sup>4</sup> (I4 blank)', '[16], 197, [1], [2 blank] p.', None, '1649', '(YYYY)', '', 'YYYY', 'Antv.', 'apud viduam I. Cnobbari', 'lat', '000012 - # a1 *2 qu : # a2 *4 va - # b1 A nu : # b2 I2 pi')
# ('c:stcv:12867804', 2, 'Moens, Adrianus', 'Adr. Moens', '', None, None, 'Privilegia a variis pontificibvs concessa ac demvm a Clemente VIII. confirmata pro fratribvs III. ord. S. Francisci de poenit. qvi svnt de capitvlo Zepperensi', 'lat', '', 'A-G<sup>8</sup> H<sup>2</sup>', '116 p.', 'First edition', '1646', 'YYYY', '', 'YYYY', 'Antverpiæ', 'apud Gvilielmvm Lesteenivm', 'lat', '164608 - # b1 A2 itu : # b2 H2 .$fol.$')
# ('c:stcv:12867845', 2, 'Drexelius, Hieremias', 'Hieremias Drexelius', '1581-1638', None, None, 'Aloe amari sed salubris succi ieivnivm', 'lat', '', 'A-Y<sup>8</sup> Z<sup>4</sup> (Z4 blank)', '[1], [1 blank], [16], 339, [3 blank] p.', None, '1650', 'YYYY', '', 'YYYY', 'Antuerpiæ', 'typis vid Ioann. Cnobbari', 'lat', '165024 - # b1 A2 quo : # b2 Z2 no')
# ('c:stcv:12867878', 2, 'F.C.A.M.R.', 'F.C.A.M.R.', '', None, None, 'Clarissimo viro D. Francisco Lams I.V.L. urbis Antuerpien. electo syndico', 'lat', '', 'A<sup>4</sup>', '[4] f.', None, '1680', '(YYYY)', '', 'YYYY', 'Antverpiæ', 'typis M. Parijs', 'lat', '000004 - # b1=b2 A2 da')
# ('c:stcv:12867885', 2, 'Bardonville', 'Bardonville', '', None, None, 'Le Confiteor dv chancelier av temps de Pasqves', 'fre', '', 'A-B<sup>2</sup>', '8 p.', None, '1649', 'YYYY', '', 'YYYY', 'Anvers [mystification]', 's.n.', 'fre', '164904 - # b1 A2 auta : # b2 B de')
# ('c:stcv:12867907', 2, 'More, Henry', 'Henricvs Morvs', '1586-1661', None, None, 'Vita et doctrina Christi domini', 'lat', '', 'A-L<sup>12</sup> M<sup>6</sup> N-2D<sup>12</sup> [2E]1', '617, [19], [2] p.', None, '1649', 'YYYY', '', 'YYYY', 'Antverpiæ', 'apud Iacobvm Mevrsivm', 'lat', '164912 - # b1 A2 eat : # b2 2D7 .$2$M')
# ('c:stcv:12867929', 2, 'Kempis, a, Joannes Wilhelmus', 'Ioannes VVilhelmus a Kempis', '', None, None, 'Praxis medica de præservatione & curatione morbi articularis & calculi', 'lat', '', 'A-C<sup>8</sup> D<sup>4</sup>', '54, [1], [1 blank] p.', None, '1648', 'YYYY', '', 'YYYY', 'Antverpiæ', 'apud viduam Ioannis Cnobbari', 'lat', '164808 - # b1 A2 .$li : # b2 D3 ij.$ra')
# ('c:stcv:12867974', 2, None, None, None, None, None, "La desiree paix entra sa majesté catholicque d'-Espagne, & les seigneurs estats des provinces unies d'Hollande, &c. Faite & signée à Munster le huictiesme de ianvier 1647", 'fre', '', '[A]<sup>2</sup>', '[2] f.', None, '1647', 'YYYY', '', 'YYYY', 'Anvers', 'Martin Binnart', 'fre', '146704 - # b1=b2 avec eig')
# ('c:stcv:12868566', 2, None, None, None, None, None, 'Epinicia sanctis martyribvs victoribvs trivmphatoribvs, quorum sacra corpora [...] in thronis [...] templi domus professæ societatis Iesu Antuerpiæ fuêre reposita', 'lat', '', 'A<sup>4</sup>', '[4] f.', None, '1655', 'YYYY', '', 'YYYY', 'Antuerpiæ', 'apud viduam Joannis Cnobbari', 'lat', '165504 - # b1 A2 o$di : # b2 A3 sunt$')
# ('c:stcv:12868625', 2, 'Rivius, Joannes', 'Ioannes Rivius', '1599-1665', None, None, 'S. Thomas a Villanova [...] a S.D.N. Alexandro papa VII. in divorvm nvmervm relatvs anno M.DC.LVIII.', 'lat', '', 'A-D<sup>4</sup>', '32 p.', None, '1658', '(YYYY-)', '', 'YYYY', 's.l.', 's.n.', 'lat', '000004 - # b1 A2 e$ca : # b2 D3 e$M')
# ('c:stcv:12868640', 2, 'Henschenius, Godefridus', 'Godefridus Henschenius', '1601-1681', None, None, 'De episcopatv Traiectensi [...] diatriba', 'lat', '', 'A-S<sup>4</sup> T1', '[1], [1 blank], [8], 113, [22], [1 blank] p.', None, '1653', 'YYYY', '', 'YYYY', 'Antverpiæ', 'typis Iacobi Mevrsii', 'lat', '165304 - # b1 A2 m$d : # b2 S3 ster')
# ('c:stcv:12868663', 2, 'Alexander VII [Pope]', 'Philomathus', '1599-1667', None, None, 'Mvsæ ivveniles', 'lat', '', '*<sup>8</sup> A-S<sup>8</sup> T<sup>4</sup>', '[1], [1 blank], [1], [1 blank], [12], 295, [1] p.', 'New edition, enlarged', '1654', 'YYYY', '', 'YYYY', 'Antverpiæ', 'ex officina Plantiniana Balthasaris Moreti', 'lat', '165408 - # a1 *3 ul : # a2 *5 m - # b1 A a : # b2 T2 urit')
# ('c:stcv:12868736', 2, 'Alvarez, Manuel', 'Emmanvel Alvarus', '1526-1583', None, None, 'Grammatica sive Institvtionvm lingvæ Latinæ liber secvndvs', 'lat', '', 'A-N<sup>8</sup>', '206, [1], [1 blank] p.', None, '1663', 'YYYY', '', 'YYYY', 'Antverpiæ', 'apud Iacobvm Mevrsivm', 'lat', '166308 - # b1 A2 ,$& : # b2 N4 um,$')
# ('c:stcv:12868749', 2, 'Alvarez, Manuel', 'Emmanvel Alvarus', '1526-1583', None, None, 'Syntaxis sive Institvtionvm lingvæ Latinæ liber tertivs. In usum studiosorum societatis Iesv', 'lat', '', 'A-K<sup>8</sup> (K7-8 blank)', '154, [1], [5 blank] p.', None, '1662', 'YYYY', '', 'YYYY', 'Antverpiæ', 'apud Iacobvm Mevrsivm', 'lat', '166208 - # b1 A2 sid : # b2 K4 e$s')
# ('c:stcv:12868755', 2, 'Alvarez, Manuel', 'Emmanvel Alvarus', '1526-1583', None, None, 'Prosodia sive Institvtionvm lingvæ Latinæ liber qvartvs. In usum studiosorum societatis Iesv', 'lat', '', 'A-I<sup>8</sup>', '141, [2], [1 blank] p.', None, '1660', 'YYYY', '', 'YYYY', 'Antverpiæ', 'apud Iacobvm Mevrsivm', 'lat', '166008 - # b1 A2 $sun : # b2 I5 nut')
# ('c:stcv:12868758', 2, 'Soarez, Cyprianus', 'Cyprianus Soarez', '1524-1593', None, None, 'De arte rhetorica libri tres', 'lat', '', '+<sup>8</sup> A-M<sup>8</sup>', '[1], [1 blank], [14], 192 p.', None, '1663', 'YYYY', '', 'YYYY', 'Antverpiæ', 'apud Iacobvm Mevrsivm', 'lat', '166308 - # a1 +2 cop : # a2 +4 ,$de - # b1 A e : # b2 M5 $in$l')
# ('c:stcv:12868994', 2, 'Torsellini, Horatius', 'Horatius Tvrsellinus', '1544-1599', None, None, 'De particvlis Latinæ orationis', 'lat', '', 'A-2E<sup>8</sup> 2F<sup>4</sup>', '392, [63], [1 blank] p.', None, '1651', 'YYYY', '', 'YYYY', 'Antverpiæ', 'apud Arnoldvm a Brakel', 'lat', '165124 - # b1 A2 ena : # b2 2F3 e,$P')
# ('c:stcv:12869036', 2, 'Fernandez, Marcos', 'Marcos Fernandez', '', None, None, 'Olla podrida a la Española, compuesta i façonada en la description de Munster en Vesfalia con salsa Sarracena i Africana', 'spa', '', '*<sup>6</sup> A-N<sup>12</sup> O<sup>6</sup>', '[1], [1 blank], [10], 324 p.', None, '1655', 'YYYY', '', 'YYYY', 'Amberes [= Amsterdam]', 'Felipe van Eyck', 'spa', '165512 - # a1 *2 abr : # a2 *4 m - # b1 A t : # b2 O4 ern')
# ('c:stcv:12869148', 2, 'Urban VIII [Pope]', 'Urbanus papa VIII', '1568-1644', None, None, 'Bulla [...] pro clero & religiosis missionariis ad propagandam fidem. In fœderatis Belgij provinciis', 'lat', '', 'A-B<sup>4</sup>', '[8] f.', None, '1658', 'YYYY', '', 'YYYY', 'Antverpiæ', 'apud Henricum Aertssium', 'lat', '165804 - # b1 A2 m$ : # b2 B3 $S')
# ('c:stcv:12869229', 2, 'Cicero, Marcus Tullius', 'M. Tvllius Cicero', '106 ante Chr.-43 ante Chr.', None, None, 'Ad Qvintvm fratrem de oratore dialogi tres', 'lat', '', 'A-N<sup>12</sup> O<sup>6</sup> (O6 blank)', '319, [2], [3 blank] p.', None, '1656', 'YYYY', '', 'YYYY', 'Antverpiæ', 'apud Iacobvm Mevrsivm', 'lat', '165612 - # b1 A2 &$ : # b2 O3 $c')
# ('c:stcv:12869264', 2, 'Stanihurstus, Guilielmus', 'Guilielmus Stanihurstus', '1601-1663', None, None, 'Dei immortalis in corpore mortali patientis historia', 'lat', '', '*<sup>8</sup> (*1 + π1) 2*<sup>8</sup> A-2C<sup>8</sup>', '[1], [1 blank], [1], [1 blank], [1], [1 blank], [28], 408, [7], [1 blank] p.', None, '1660', 'YYYY', '', 'YYYY', 'Antverpiæ', 'apud viduam & hæredes Joannis Cnobbari', 'lat', '166008 - # a1 *3 u : # a2 2*2 ane - # b1 A nd : # b2 2C4 rtnus$e')
# ('c:stcv:12869479', 2, 'Favart, Charles-Simon', 'Favat [!]', '1710-1792', None, None, "l'Anglois a Bordeaux; comedie en un acte et en vers libres", 'fre', '', 'A<sup>8</sup> B-C<sup>4</sup> D-E<sup>8</sup>', '64 p.', None, '1763', 'YYYY', '', 'YYYY', 'Bruxelles', 'JJ. Boucherie', 'fre', '176308 - # b1 A2 $me : # b2 E4 e$pl')
# ('c:stcv:12869497', 2, 'Favart, Charles-Simon', 'Favart, Charles-Simon', '1710-1792', None, None, 'La fausse duègne ou Le jaloux corrigé par force, opera-comique en deux actes', 'fre', '', 'A-G<sup>8</sup> [H]1', '114 p.', None, '1756', 'YYYY', '', 'YYYY', 's.l.', 's.n.', 'fre', '175608 - # b1 A2 e$ : # b2 G4 otre')
# ('c:stcv:12869500', 2, None, None, None, None, None, "Il étoit tems ou l'Ecuyer temeraire, petit opera-comique en un acte", 'fre', '', 'A-B<sup>8</sup> (B8 blank)', '28, [2], [2 blank] p.', None, '1756', 'YYYY', '', 'YYYY', 'Bruxelles', 'Jean Joseph Boucherie', 'fre', "175608 - # b1 A2 e$l' : # b2 B3 ent")
# ('c:stcv:12869588', 2, 'Sedaine, Michel Jean', 'Sedaine, Michel Jean', '1719-1797', None, None, 'Rose et Colas, comédie en un acte', 'fre', '', 'A-D<sup>8</sup> E<sup>4</sup>', '[1], [1 blank], 62, [3], [1 blank] p.', None, '1764', 'YYYY', '', 'YYYY', 'Bruxelles', 'Jean Joseph Boucherie', 'fre', '176408 - # b1 A2 Roi : # b2 D4 s$m')
# ('c:stcv:12869609', 2, 'Romagnesi, Jean-Antoine', 'Romagnesi', '1690-1742', None, None, 'Samson', 'fre', '', 'A-E<sup>6</sup> F<sup>4</sup>', '78 [= 68] p.', None, '1734', 'YYYY', '', 'YYYY', 'Bruxelles', 'Nicolas Stryckwant', 'fre', '173412 - # b1 A2 $d : # b2 F2 ont')
# ('c:stcv:12869812', 2, 'Puteanus, Erycius', 'E. Pvteanus', '1574-1646', None, None, 'De indvciis avt pace Belgarvm dissertationes variæ', 'lat', '', 'A-F<sup>12</sup> G<sup>4</sup> (lacks G4, blank?)', '150 p.', None, '1633', 'YYYY', '', 'YYYY', 'Elevtheropoli', 's.n.', 'lat', '163312 - # b1 A2 stem : # b2 G3 sis$')
# ('c:stcv:12869845', 2, 'Tamburino, Thomas', 'Thomas Tambvrinus', '', None, None, 'De sacrificio missæ expedite celebrando libri tres', 'lat', '', 'A-2K<sup>12</sup>', '[1], [1 blank], [26], 485 [= 729], [22], [1 blank] p.', 'New edition', '1656', 'YYYY', '', 'YYYY', 'Antverpiæ', 'apud Iacobvm Mevrsivm', 'lat', '165612 - # b1 A2 m$c : # b2 2K6 ua$rat')
# ('c:stcv:12869872', 2, 'P.N.S.N.', 'P.N.S.N.', '', None, None, 'Disceptatio et justa defensio septem controversiarum [...] super collatione verbo scriptoque habitâ inter duos patres Embricenses è societate Iesu, & duos ministros reformatæ religionis. Adversus D. Petrum Cabeljavium, ministrum Leidensem', 'lat', '', '*<sup>8</sup> 2*<sup>8</sup> (- 2*8) A-X<sup>8</sup> (lacks X8, blank?)', '[1], [1 blank], [27], [1 blank], 332, [1], [1 blank] p.', None, '1657', 'YYYY', '', 'YYYY', 'Antverpiæ', 'apud Cornelium Woons', 'lat', '165708 - # a1 *2 iu : # a2 2*5 ores$ - # b1 A au : # b2 X5 t:$')
# ('c:stcv:12869899', 2, 'Cambry, de, P.', 'P. de Cambry', '', None, None, "Abbregé de la vie de dame Ienne de Cambry, premierement religieuse de l'ordre de S. Augustin à Tournay, & depuis sœur Ienne Marie de la Presentation recluse lez Lille", 'fre', '', 'A-2G<sup>4</sup> (and 1 engraved folio)', '224, [13], [1 blank], [1], [1 blank] p.', None, '1659', 'YYYY', '', 'YYYY', 'Anvers', 'Iacques Mesens', 'fre', '165904 - # b1 A2 ur : # b2 2G es$')
# ('c:stcv:12869970', 2, 'Urban VIII [Pope]', 'Vrbanus [...] papa VIII', '1568-1644', None, None, 'Confirmatio constitutionum Pij papæ V. & Gregorij XIII. prohibentium quasdam theologorum sententias, & opiniones. Nec non prohibitio libri, cui titulus, Augustinus, Cornelij Iansenij [...] excusi Lovanij, typis Iacobi Zegeri, anno 1640.', 'lat', '', 'A-D<sup>4</sup> (D4 blank)', '[15], [1 blank] f.', None, '1651', 'YYYY', '', 'YYYY', 'Brvxellæ', 'typis Huberti Antonij Velpij', 'lat', '165104 - # b1 A2 ro : # b2 D3 llari')
# ('c:stcv:12869997', 2, 'Chifflet, Laurent', 'Lavrent Chiflet', '1598-1658', None, None, "Essay d'vne parfaite grammaire de la langve françoise", 'fre', '', 'ã<sup>8</sup> A-P<sup>8</sup> Q<sup>4</sup>', '[1], [1 blank], [14], 247, [1] p.', None, '1659', 'YYYY', '', 'YYYY', 'Anvers', 'Iacqves van Mevrs', 'fre', '165908 - # a1 ã2 dic : # a2 ã3 $la - # b1 A u : # b2 Q2 our')
# ('c:stcv:12870045', 2, 'Cicero, Marcus Tullius', 'M. T. Cicero', '106 ante Chr.-43 ante Chr.', None, None, 'Celebriores sententiæ, apophthegmata et similitvdines ex operibus M.T. Ciceronis collectæ', 'lat', '', 'A-2C<sup>8/4</sup>', '296, [15], [1 blank] p.', None, '1651', 'YYYY', '', 'YYYY', 'Antverpiæ', 'apud Henr. Aertssens', 'lat', '165124 - # b1 A2 $D : # b2 2C m')
# ('c:stcv:12870054', 2, None, None, None, None, None, 'Catechisme ov Doctrine chrestienne divisée en cinq parties, et quarante & vne leçons', 'fre', '', 'A-D<sup>8</sup>', '63, [1] p.', None, '1659', 'YYYY', '', 'YYYY', 'Anvers', 'Arnout van Braeckel', 'fre', '165908 - # b1 A2 om : # b2 D2 e$Ba')
# ('c:stcv:12870121', 2, 'Drexelius, Hieremias', 'Hieremias Drexelius', '1581-1638', None, None, 'Rhetorica cælestis seu Attente precandi scientia', 'lat', '', 'A-X<sup>8</sup> Z-2F<sup>8</sup> 2G1', '[1], [1 blank], [14], 434 p.', None, '1651', 'YYYY', '', 'YYYY', 'Antverpiæ', 'apud viduam Ioann. Cnobbari', 'lat', '165124 - # b1 A2 nn : # b2 2G nu')

# %%
# The second cell matches all 100 queries to the HPB database using SRU-CQL. The result is the xml in string format.

import urllib.parse
import urllib.request
import urllib.error
import time

# This is the base of the link:
HPB = 'https://sru.gbv.de/hpb?version=2.0&operation=searchRetrieve&query='

# I define how I want to clean the input search:
def clean(string: str) -> str:
    string = string.strip()
    string = string.replace('.', '') # I delete all full stops, as including those yielded wrong results.
    string = string.casefold() 
    string = urllib.parse.quote(string)
    return string


# I define on what metadata I want to match. I decided to match on the title:
def search_for(book: list) -> str:
    search_for = clean(book[7]) # The seventh element in the tuple contains the title
    return search_for

# I query the HPB database:
def query_HPB(search: str) -> bytes:
    time.sleep(2)

    url = HPB + search + '&startRecord=1&maximumRecords=100&recordSchema=marcxml'
    try:
        with urllib.request.urlopen(url) as query:
            return query.read()
    except urllib.error.HTTPError as HTTPerr:
        exit(HTTPerr.code)
    except urllib.error.URLError as URLerr:
        exit(URLerr)

search = search_for(data[0]) # I test this out on the first title in the list from stcv.
print(str(query_HPB(search)))
# Out:
# b'<?xml version="1.0" encoding="UTF-8"?>\n<zs:searchRetrieveResponse xmlns:zs="http://docs.oasis-open.org/ns/search-ws/sruResponse"><zs:numberOfRecords>1</zs:numberOfRecords><zs:records><zs:record><zs:recordSchema>marcxml</zs:recordSchema><zs:recordXMLEscaping>xml</zs:recordXMLEscaping><zs:recordData><record xmlns="http://www.loc.gov/MARC21/slim">\n  <leader>xxxxxnam a22yyyyy c 4500</leader>\n  <controlfield tag="001">15364091X</controlfield>\n  <controlfield tag="003">DE-601</controlfield>\n  <controlfield tag="005">20210820093419.0</controlfield>\n  <controlfield tag="008">090409s1797                  000 0 fre d</controlfield>\n  <datafield tag="035" ind1=" " ind2=" ">\n    <subfield code="a">BE-AnVE.c:stcv:12854444</subfield>\n  </datafield>\n  <datafield tag="040" ind1=" " ind2=" ">\n    <subfield code="b">ger</subfield>\n    <subfield code="c">GBVCP</subfield>\n  </datafield>\n  <datafield tag="041" ind1="0" ind2=" ">\n    <subfield code="a">fre</subfield>\n  </datafield>\n  <datafield tag="044" ind1=" " ind2=" ">\n    <subfield code="c">ZZ</subfield>\n  </datafield>\n  <datafield tag="100" ind1="0" ind2=" ">\n    <subfield code="a">Ernst, Simon-Pierre</subfield>\n    <subfield code="d">1744-1817</subfield>\n    <subfield code="e">*aut</subfield>\n  </datafield>\n  <datafield tag="245" ind1="1" ind2="0">\n    <subfield code="a">Apologie des ministres du culte, qui ont pr\xc3\xaat\xc3\xa9 la d\xc3\xa9claration exig\xc3\xa9e par la loi du 7 vend\xc3\xa9m. an 4. contre les critiques de mm. D\xc3\xa9doyar &amp; Vanhoren, les Motifs de Malines &amp; autres brochures</subfield>\n    <subfield code="c">Simon-Pierre Ernst [aut]</subfield>\n  </datafield>\n  <datafield tag="264" ind1="3" ind2="1">\n    <subfield code="a">[s.l.]</subfield>\n    <subfield code="b">[s.n.]</subfield>\n    <subfield code="c">1797</subfield>\n  </datafield>\n  <datafield tag="300" ind1=" " ind2=" ">\n    <subfield code="a">xxviij, 142 p. \xcf\x80&lt;sup&gt;2&lt;/sup&gt; a&lt;sup&gt;8&lt;/sup&gt; b&lt;sup&gt;4&lt;/sup&gt; A-H&lt;sup&gt;8&lt;/sup&gt; I&lt;sup&gt;6&lt;/sup&gt; (- I6) K&lt;sup&gt;2&lt;/sup&gt;</subfield>\n  </datafield>\n  <datafield tag="500" ind1=" " ind2=" ">\n    <subfield code="a">Possibly printed in the Southern Netherlands</subfield>\n  </datafield>\n  <datafield tag="500" ind1=" " ind2=" ">\n    <subfield code="a">Sheet count: 10.625</subfield>\n  </datafield>\n  <datafield tag="500" ind1=" " ind2=" ">\n    <subfield code="a">STCV Typographical term: Typeface Roman , UID (ALOI): (BE-AnVE)a::t090:1</subfield>\n  </datafield>\n  <datafield tag="500" ind1=" " ind2=" ">\n    <subfield code="a">STCV Typographical term: Typographical title page , UID (ALOI): (BE-AnVE)a::t210:1</subfield>\n  </datafield>\n  <datafield tag="500" ind1=" " ind2=" ">\n    <subfield code="a">The fingerprint identifier follows the rules used by the STCN. </subfield>\n  </datafield>\n  <datafield tag="856" ind1="4" ind2="2">\n    <subfield code="u">http://lib.ugent.be/europeana/900000060421</subfield>\n    <subfield code="q">html</subfield>\n    <subfield code="z">Electronically available: UB-GENT ACC.000589. Free electronic access</subfield>\n  </datafield>\n  <datafield tag="950" ind1=" " ind2=" ">\n    <subfield code="a">Church history and dogmatic history</subfield>\n    <subfield code="2">DE-601</subfield>\n  </datafield>\n  <datafield tag="950" ind1=" " ind2=" ">\n    <subfield code="a">History: Belgium and Luxembourg</subfield>\n    <subfield code="2">DE-601</subfield>\n  </datafield>\n  <datafield tag="950" ind1=" " ind2=" ">\n    <subfield code="a">Period documents</subfield>\n    <subfield code="2">DE-601</subfield>\n  </datafield>\n  <datafield tag="951" ind1=" " ind2=" ">\n    <subfield code="a">BO</subfield>\n  </datafield>\n</record></zs:recordData><zs:recordPosition>1</zs:recordPosition></zs:record></zs:records><zs:echoedSearchRetrieveRequest><zs:version>2.0</zs:version><zs:query>apologie des ministres du culte, qui ont pr\xc3\xaat\xc3\xa9 la d\xc ...

# %%
# Now, I create a dictionary which includes all relevant metadata of the titles from the HPB database.

import lxml.etree
identifier = search_for(data[0]) # I use the first title to try this part out.
search1 = HPB + identifier

# This is the namespace of the "actual" records:
HPB_XML_NS = r'{http://www.loc.gov/MARC21/slim}'
# This is the namespace of the meta-meta information:
HPB_XML_NS1 = "http://docs.oasis-open.org/ns/search-ws/sruResponse"



def parse(oai: bytes) -> list:
    root = lxml.etree.fromstring(oai)
    records = []
    for record in root.iter(f"{HPB_XML_NS}record"):
        metadata = {}
        index = 0
        for datafield in record.iter(f"{HPB_XML_NS}datafield"):
            for key, value in datafield.items():
                if key == "tag":
                    for subfield in datafield:
                        index += 1
                        for _, code in subfield.items():
                            metadata[index] = {"tag": value,
                                               "code": code,
                                               "code2": subfield.text}
        records.append(metadata)
    return records

parsed = parse(query_HPB(search1))
sqlbook = data[0]
hpbbook = parsed[0]
print(parsed[0])
# Out:
# {1: {'tag': '035', 'code': 'a', 'code2': 'BE-AnVE.c:stcv:12854444'}, 2: {'tag': '040', 'code': 'b', 'code2': 'ger'}, 3: {'tag': '040', 'code': 'c', 'code2': 'GBVCP'}, 4: {'tag': '041', 'code': 'a', 'code2': 'fre'}, 5: {'tag': '044', 'code': 'c', 'code2': 'ZZ'}, 6: {'tag': '100', 'code': 'a', 'code2': 'Ernst, Simon-Pierre'}, 7: {'tag': '100', 'code': 'd', 'code2': '1744-1817'}, 8: {'tag': '100', 'code': 'e', 'code2': '*aut'}, 9: {'tag': '245', 'code': 'a', 'code2': 'Apologie des ministres du culte, qui ont prêté la déclaration exigée par la loi du 7 vendém. an 4. contre les critiques de mm. Dédoyar & Vanhoren, les Motifs de Malines & autres brochures'}, 10: {'tag': '245', 'code': 'c', 'code2': 'Simon-Pierre Ernst [aut]'}, 11: {'tag': '264', 'code': 'a', 'code2': '[s.l.]'}, 12: {'tag': '264', 'code': 'b', 'code2': '[s.n.]'}, 13: {'tag': '264', 'code': 'c', 'code2': '1797'}, 14: {'tag': '300', 'code': 'a', 'code2': 'xxviij, 142 p. π<sup>2</sup> a<sup>8</sup> b<sup>4</sup> A-H<sup>8</sup> I<sup>6</sup> (- I6) K<sup>2</sup>'}, 15: {'tag': '500', 'code': 'a', 'code2': 'Possibly printed in the Southern Netherlands'}, 16: {'tag': '500', 'code': 'a', 'code2': 'Sheet count: 10.625'}, 17: {'tag': '500', 'code': 'a', 'code2': 'STCV Typographical term: Typeface Roman , UID (ALOI): (BE-AnVE)a::t090:1'}, 18: {'tag': '500', 'code': 'a', 'code2': 'STCV Typographical term: Typographical title page , UID (ALOI): (BE-AnVE)a::t210:1'}, 19: {'tag': '500', 'code': 'a', 'code2': 'The fingerprint identifier follows the rules used by the STCN. '}, 20: {'tag': '856', 'code': 'u', 'code2': 'http://lib.ugent.be/europeana/900000060421'}, 21: {'tag': '856', 'code': 'q', 'code2': 'html'}, 22: {'tag': '856', 'code': 'z', 'code2': 'Electronically available: UB-GENT ACC.000589. Free electronic access'}, 23: {'tag': '950', 'code': 'a', 'code2': 'Church history and dogmatic history'}, 24: {'tag': '950', 'code': '2', 'code2': 'DE-601'}, 25: {'tag': '950', 'code': 'a', 'code2': 'History: Belgium and Luxembourg'}, 26: {'tag': '950', 'code': '2', 'code2': 'DE-601'}, 27: {'tag': '950', 'code': 'a', 'code2': 'Period documents'}, 28: {'tag': '950', 'code': '2', 'code2': 'DE-601'}, 29: {'tag': '951', 'code': 'a', 'code2': 'BO'}}

# %%
# There is also a possibility that the author's name is formatted differently than in the HPB database. For that
# reason, I create a function that switches the first and last name:

def reverse_name(hpbbook):
    for item in hpbbook:
        if hpbbook[item]['tag'] == '100' and hpbbook[item]['code'] == 'a':
            author = hpbbook[item]['code2']
            if ',' in author:
                author_firstname_surname = author.split(',')[1] + ' ' + author.split(',')[0]
                return author_firstname_surname
            else:
                return author
print(reverse_name(hpbbook))
# Out:
#  Simon-Pierre Ernst

# %%
# I make a definition that checks whether the author's name from the stcv database is the same in the hpb database:


def author_name_match(sqlbook: list, hpbbook: dict):
    for item in hpbbook:
        if hpbbook[item]['tag'] == '100' and hpbbook[item]['code'] == 'a':
            author = hpbbook[item]['code2']
            if author:
                if author == sqlbook[2] or reverse_name(hpbbook) == sqlbook[2]:
                    return True
                else:
                    return False
            else:
                return False
        
author_name_match(sqlbook, parsed[0]) # I try it out with the first work.
# Out:
# True

# %%
# I make a definition that checks whether the date from the stcv database is the same in the hpb database:

def date_match(sqlbook: list, hpbbook: dict):
    for item in hpbbook:
        if hpbbook[item]['tag'] == '100' and hpbbook[item]['code'] == 'd':
            date = hpbbook[item]['code2']
            if date == sqlbook[4]:
                return True
            else:
                return False

date_match(sqlbook, parsed[0]) # I try it out with the first work.
# Out:
# True

# %%
# This is the eventual desired outcome.

def result_HPB(hpbbook) -> str:
    for item in hpbbook:
        if hpbbook[item]['tag'] == '035' and hpbbook[item]['code'] == 'a':
            result = hpbbook[item]['code2']
            return result

result_HPB(parsed[0])
# Out:
# 'BE-AnVE.c:stcv:12854444'

# %%
# This is to select the best match to be returned: in the event of multiple matches, I only want the book that 
# matches the author and date both.

def find_best_match(sqlbook: list, hpbbooks: list) -> dict:
    best_match = hpbbooks[0] # I stack the first hit as temporary best match.
    author_matched = False
    for hpbbook in hpbbooks:
        if author_name_match(sqlbook, hpbbook) and not author_matched: # if this is the first time the author matches:
            best_match = hpbbook
            author_matched = True
        if author_name_match(sqlbook, hpbbook) and date_match(sqlbook, hpbbook): 
            # This is the perfect match. If these criteria fit, end the loop and return this result.
            return hpbbook
        else:
            # If the date and author do not match:
            #print(f"{result_HPB(hpbbook)} \t There is no perfect match, but this one comes close.")
            return hpbbook
            #return f"{hpbbook}\t There is no perfect match, but this one comes close."
    return best_match
find_best_match(sqlbook, parsed)
# Out:
# {1: {'tag': '035', 'code': 'a', 'code2': 'BE-AnVE.c:stcv:12854444'},
#  2: {'tag': '040', 'code': 'b', 'code2': 'ger'},
#  3: {'tag': '040', 'code': 'c', 'code2': 'GBVCP'},
#  4: {'tag': '041', 'code': 'a', 'code2': 'fre'},
#  5: {'tag': '044', 'code': 'c', 'code2': 'ZZ'},
#  6: {'tag': '100', 'code': 'a', 'code2': 'Ernst, Simon-Pierre'},
#  7: {'tag': '100', 'code': 'd', 'code2': '1744-1817'},
#  8: {'tag': '100', 'code': 'e', 'code2': '*aut'},
#  9: {'tag': '245',
#   'code': 'a',
#   'code2': 'Apologie des ministres du culte, qui ont prêté la déclaration exigée par la loi du 7 vendém. an 4. contre les critiques de mm. Dédoyar & Vanhoren, les Motifs de Malines & autres brochures'},
#  10: {'tag': '245', 'code': 'c', 'code2': 'Simon-Pierre Ernst [aut]'},
#  11: {'tag': '264', 'code': 'a', 'code2': '[s.l.]'},
#  12: {'tag': '264', 'code': 'b', 'code2': '[s.n.]'},
#  13: {'tag': '264', 'code': 'c', 'code2': '1797'},
#  14: {'tag': '300',
#   'code': 'a',
#   'code2': 'xxviij, 142 p. π<sup>2</sup> a<sup>8</sup> b<sup>4</sup> A-H<sup>8</sup> I<sup>6</sup> (- I6) K<sup>2</sup>'},
#  15: {'tag': '500',
#   'code': 'a',
#   'code2': 'Possibly printed in the Southern Netherlands'},
#  16: {'tag': '500', 'code': 'a', 'code2': 'Sheet count: 10.625'},
#  17: {'tag': '500',
#   'code': 'a',
#   'code2': 'STCV Typographical term: Typeface Roman , UID (ALOI): (BE-AnVE)a::t090:1'},
#  18: {'tag': '500',
#   'code': 'a',
#   'code2': 'STCV Typographical term: Typographical title page , UID (ALOI): (BE-AnVE)a::t210:1'},
#  19: {'tag': '500',
#   'code': 'a',
#   'code2': 'The fingerprint identifier follows the rules used by the STCN. '},
#  20: {'tag': '856',
#   'code': 'u',
#   'code2': 'http://lib.ugent.be/europeana/900000060421'},
#  21: {'tag': '856', 'code': 'q', 'code2': 'html'},
#  22: {'tag': '856',
#   'code': 'z',
#   'code2': 'Electronically available: UB-GENT ACC.000589. Free electronic access'},
#  23: {'tag': '950',
#   'code': 'a',
#   'code2': 'Church history and dogmatic history'},
#  24: {'tag': '950', 'code': '2', 'code2': 'DE-601'},
#  25: {'tag': '950', 'code': 'a', 'code2': 'History: Belgium and Luxembourg'},
#  26: {'tag': '950', 'code': '2', 'code2': 'DE-601'},
#  27: {'tag': '950', 'code': 'a', 'code2': 'Period documents'},
#  28: {'tag': '950', 'code': '2', 'code2': 'DE-601'},
#  29: {'tag': '951', 'code': 'a', 'code2': 'BO'}}

# %%
# This function returns the eventual outcome: the identifier of the STCV book, 
# and the identifier of the best HPB match.

def final(sqlbook: list, hpbbook: dict) -> str:
    display = sqlbook[0]+ ' === ' + result_HPB(hpbbook)
    
    if not author_name_match(sqlbook, hpbbook) and not date_match(sqlbook, hpbbook):
        display += '\tBut author and date didn\'t match' 
    elif not author_name_match(sqlbook, hpbbook):
        display += '\tBut author didn\'t match'
    elif not date_match(sqlbook, hpbbook):
        display += '\tBut date didn\'t match'
    else:
        display += '\tPotential match'
    return display

print(final(sqlbook, parsed[0])) # Again, I try this out on the first work.
# Out:
# c:stcv:12854444 === BE-AnVE.c:stcv:12854444	Potential match

# %%
def find_hpb_match(sqlbook: list) -> str:
    search = search_for(sqlbook)
    identifier = search_for(book)
    search_url = HPB + identifier
    parsed = parse(query_HPB(search_url))
    best_match = find_best_match(sqlbook, parsed)
    return(final(sqlbook, best_match))
    

ind = 0
for book in data:
    ind +=1
    print(str(ind)+ '. ' + find_hpb_match(book))
# Out:
# 1. c:stcv:12854444 === BE-AnVE.c:stcv:12854444	Potential match
# 2. c:stcv:12854501 === BE-AnVE.c:stcv:12913022	But author and date didn't match
# 3. c:stcv:12854549 === (OCoLC)253314165	Potential match
# 4. c:stcv:12854587 === BE-AnVE.c:stcv:12854587	But author and date didn't match
# 5. c:stcv:12854599 === BE-AnVE.c:stcv:12854599	But author and date didn't match
# 6. c:stcv:12857052 === BE-AnVE.c:stcv:12857052	But date didn't match
# 7. c:stcv:12857069 === BE-AnVE.c:stcv:12857069	Potential match
# 8. c:stcv:12857131 === BE-AnVE.c:stcv:12857131	But date didn't match
# 9. c:stcv:12857158 === (OCoLC)48731412	But author and date didn't match
# 10. c:stcv:12857275 === BE-AnVE.c:stcv:12857275	Potential match
# 11. c:stcv:12857374 === BE-AnVE.c:stcv:12857374	But author didn't match
# 12. c:stcv:12857912 === BE-AnVE.c:stcv:12902263	Potential match
# 13. c:stcv:12857923 === BE-AnVE.c:stcv:12857923	But author and date didn't match
# 14. c:stcv:12858124 === BE-AnVE.c:stcv:12858124	But date didn't match
# 15. c:stcv:12858392 === BE-AnVE.c:stcv:12858392	Potential match
# 16. c:stcv:12858408 === BE-AnVE.c:stcv:12867845	Potential match
# 17. c:stcv:12858413 === BE-AnVE.c:stcv:12922152	Potential match
# 18. c:stcv:12858468 === (OCoLC)169500241 	But author and date didn't match
# 19. c:stcv:12858494 === BE-AnVE.c:stcv:12858509	But author and date didn't match
# 20. c:stcv:12858622 === BE-AnVE.c:stcv:12858622	Potential match
# 21. c:stcv:12858690 === BE-AnVE.c:stcv:12858690	Potential match
# 22. c:stcv:12858729 === (OCoLC)168185284 	But date didn't match
# 23. c:stcv:12858795 === BE-AnVE.c:stcv:12858795	Potential match
# 24. c:stcv:12859250 === BE-AnVE.c:stcv:12859250	But author didn't match
# 25. c:stcv:12859427 === IT-ICCU.CFIE044723	But author and date didn't match
# 26. c:stcv:12859712 === FR-341725201.SUDOC.140484825	But author and date didn't match
# 27. c:stcv:12859754 === NL-0100030000.EPE.854160108	But author and date didn't match
# 28. c:stcv:12859820 === CZ-PrNK.STT.stt20110043096	But author and date didn't match
# 29. c:stcv:12859871 === BE-AnVE.c:stcv:7088533	But author and date didn't match
# 30. c:stcv:12859905 === BE-AnVE.c:stcv:12859905	But author and date didn't match
# 31. c:stcv:12859931 === BE-AnVE.c:stcv:12859931	But author and date didn't match
# 32. c:stcv:12860028 === NL-UtRU.01.000671780	But author and date didn't match
# 33. c:stcv:12860136 === BE-AnVE.c:stcv:12860136	But date didn't match
# 34. c:stcv:12860498 === BE-AnVE.c:stcv:12860498	But author and date didn't match
# 35. c:stcv:12860697 === NL-0100030000.EPE.854160108	But author and date didn't match
# 36. c:stcv:12860711 === NL-0100030000.EPE.854160108	But author and date didn't match
# 37. c:stcv:12860736 === NL-0100030000.EPE.854160108	But author and date didn't match
# 38. c:stcv:12861541 === BE-AnVE.c:stcv:12912859	Potential match
# 39. c:stcv:12861606 === NL-0100030000.EPE.854160108	But author and date didn't match
# 40. c:stcv:12861734 === IT-ICCU.MOLE002376	But date didn't match
# 41. c:stcv:12861760 === IT-ICCU.MOLE002376	But date didn't match
# 42. c:stcv:12861798 === BE-AnVE.c:stcv:12861798	But author and date didn't match
# 43. c:stcv:12861813 === NL-0100030000.EPE.854160108	But author and date didn't match
# 44. c:stcv:12862032 === BE-AnVE.c:stcv:12862032	But author and date didn't match
# 45. c:stcv:12862035 === BE-AnVE.c:stcv:12862035	But author and date didn't match
# 46. c:stcv:12862038 === (OCoLC)168203848 	But author and date didn't match
# 47. c:stcv:12862053 === BE-KBR00.CAT.1_1493039	But author and date didn't match
# 48. c:stcv:12862058 === BE-AnVE.c:stcv:12862058	But author and date didn't match
# 49. c:stcv:12862118 === PlWaU.01.xx002770867	But author didn't match
# 50. c:stcv:12862125 === BE-AnVE.c:stcv:12862125	Potential match
# 51. c:stcv:12862153 === (OCoLC)252273134	But date didn't match
# 52. c:stcv:12862168 === FR-751131015.CG.FRBNF315692890000009	But author and date didn't match
# 53. c:stcv:12863004 === BE-AnVE.c:stcv:12863004	But date didn't match
# 54. c:stcv:12865436 === IT-ICCU.UM1E005908	But author and date didn't match
# 55. c:stcv:12865677 === (OCoLC)168091753 	But author and date didn't match
# 56. c:stcv:12865828 === BE-AnVE.c:stcv:7009616	But date didn't match
# 57. c:stcv:12866841 === IT-ICCU.UBOE032443	But author and date didn't match
# 58. c:stcv:12866854 === FR-751131015.CG.FRBNF325889210000005	Potential match
# 59. c:stcv:12866862 === FR-341725201.SUDOC.100155820	But author and date didn't match
# 60. c:stcv:12866867 === FR-751131015.CG.FRBNF386553610000007	But author and date didn't match
# 61. c:stcv:12866905 === IT-ICCU.MUS0038800	But author and date didn't match
# 62. c:stcv:12866912 === (OCoLC)839004569	Potential match
# 63. c:stcv:12866920 === BE-KBR00.CAT.1_194739	But author and date didn't match
# 64. c:stcv:12866939 === (OCoLC)168023700 	But author and date didn't match
# 65. c:stcv:12867300 === BE-AnVE.c:stcv:12867300	But date didn't match
# 66. c:stcv:12867792 === BE-AnVE.c:stcv:12867792	Potential match
# 67. c:stcv:12867804 === BE-AnVE.c:stcv:12867804	But author and date didn't match
# 68. c:stcv:12867845 === BE-AnVE.c:stcv:12867845	Potential match
# 69. c:stcv:12867878 === BE-AnVE.c:stcv:12867878	But date didn't match
# 70. c:stcv:12867885 === BE-AnVE.c:stcv:12867885	But date didn't match
# 71. c:stcv:12867907 === CZ-PrNK.STT.stt20140112456	But author and date didn't match
# 72. c:stcv:12867929 === BE-AnVE.c:stcv:12867929	But author and date didn't match
# 73. c:stcv:12867974 === BE-AnVE.c:stcv:12867974	But author and date didn't match
# 74. c:stcv:12868566 === BE-AnVE.c:stcv:12868566	But author and date didn't match
# 75. c:stcv:12868625 === BE-AnVE.c:stcv:12868625	Potential match
# 76. c:stcv:12868640 === BE-AnVE.c:stcv:12868640	Potential match
# 77. c:stcv:12868663 === CZ-PrNK.STT.stt20150137822	But author didn't match
# 78. c:stcv:12868736 === BE-AnVE.c:stcv:12868736	Potential match
# 79. c:stcv:12868749 === BE-AnVE.c:stcv:12868749	Potential match
# 80. c:stcv:12868755 === BE-AnVE.c:stcv:12868755	Potential match
# 81. c:stcv:12868758 === IT-ICCU.VIAE020579	But author and date didn't match
# 82. c:stcv:12868994 === GB-StGlU.01.b17392044	But author and date didn't match
# 83. c:stcv:12869036 === BE-AnVE.c:stcv:12869036	But date didn't match
# 84. c:stcv:12869148 === BE-AnVE.c:stcv:12869148	But author didn't match
# 85. c:stcv:12869229 === FR-341725201.SUDOC.123906024	But author and date didn't match
# 86. c:stcv:12869264 === DE-604.VK.BV040988239	But author didn't match
# 87. c:stcv:12869479 === US-icn.01.365209	But author didn't match
# 88. c:stcv:12869497 === BE-AnVE.c:stcv:12869497	Potential match
# 89. c:stcv:12869500 === BE-AnVE.c:stcv:12869500	But author and date didn't match
# 90. c:stcv:12869588 === DE-604.VK.BV023239434	But author and date didn't match
# 91. c:stcv:12869609 === (OCoLC)169879124 	But author and date didn't match
# 92. c:stcv:12869812 === BE-AnVE.c:stcv:12869812	Potential match
# 93. c:stcv:12869845 === (OCoLC)254291581	But author and date didn't match
# 94. c:stcv:12869872 === BE-AnVE.c:stcv:12869872	But date didn't match
# 95. c:stcv:12869899 === BE-AnVE.c:stcv:12869899	But author and date didn't match
# 96. c:stcv:12869970 === BE-AnVE.c:stcv:12869970	But author didn't match
# 97. c:stcv:12869997 === BE-AnVE.c:stcv:3197053	Potential match
# 98. c:stcv:12870045 === BE-AnVE.c:stcv:12870045	But date didn't match
# 99. c:stcv:12870054 === BE-AnVE.c:stcv:12870054	But author and date didn't match
# 100. c:stcv:12870121 === DE-604.VK.BV010204729	But author didn't match

# %%
# I used these urls to check my matches manually:
# hpb: https://kxp.k10plus.de/DB=1.77/SET=1/TTL=1/CMD?MATCFILTER=N&MATCSET=N&ACT0=&ACT=SRCHA&IKT=1016&SRT=YOP&ADI_IKT9200=&TRM=cid+BE-AnVE.c%3Astcv%3A12870121
# stcv: https://anet.be/brocade/brocade.phtml?UDdesk=uantwerpen&UDses=130246205%3A829800&UDstate=1&UDmode=&UDaccess=&UDrou=_EntryC%3Abopwexe&RDcgi=advancedsearchlinkexplorator&CDopSe=690538487&CDopSt=6&CDopLv=1&CDopOp=stcvopac
